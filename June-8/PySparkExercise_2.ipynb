# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder\
      .appName("PySpark Day---1")\
      .getOrCreate()

# %%
data = [
(1, "Rahul Sharma", "Hyderabad", "Electronics", "Laptop", 1, 65000, "Pending"),
(2, "Priya Reddy", "Bangalore", "Electronics", "Mobile", 2, 25000, "Delivered"),
(3, "Amit Kumar", "Mumbai", "Furniture", "Chair", 4, 3500, "Pending"),
(4, "Sneha Patel", "Chennai", "Electronics", "Tablet", 1, 30000, "Cancelled"),
(5, "Farhan Ali", "Delhi", "Furniture", "Table", 2, 12000, "Delivered"),
(6, "Neha Singh", "Hyderabad", "Fashion", "Shoes", 3, 2500, "Delivered"),
(7, "Arjun Verma", "Pune", "Fashion", "Watch", 1, 8000, "Pending"),
(8, "Meera Nair", "Bangalore", "Electronics", "TV", 1, 45000, "Delivered"),
(9, "Kiran Rao", "Hyderabad", "Furniture", "Desk", 1, 15000, "Delivered"),
(10, "Ravi Kumar", "Mumbai", "Electronics", "Mobile", 1, 28000, "Delivered")]

# %%
columns = [
"order_id",
"customer_name",
"city",
"category",
"product",
"quantity",
"price",
"order_status"
]

# %%
df = spark.createDataFrame(data, columns)
df.show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|     Pending|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|
# ...

# %%
df.show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|     Pending|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|
# ...

# %%
df.select("customer_name", "city", "product").show()
# Out:
# +-------------+---------+-------+
# |customer_name|     city|product|
# +-------------+---------+-------+
# | Rahul Sharma|Hyderabad| Laptop|
# |  Priya Reddy|Bangalore| Mobile|
# |   Amit Kumar|   Mumbai|  Chair|
# |  Sneha Patel|  Chennai| Tablet|
# |   Farhan Ali|    Delhi|  Table|
# |   Neha Singh|Hyderabad|  Shoes|
# |  Arjun Verma|     Pune|  Watch|
# |   Meera Nair|Bangalore|     TV|
# |    Kiran Rao|Hyderabad|   Desk|
# |   Ravi Kumar|   Mumbai| Mobile|
# +-------------+---------+-------+

# %%
df.select("product","price").show()
# Out:
# +-------+-----+
# |product|price|
# +-------+-----+
# | Laptop|65000|
# | Mobile|25000|
# |  Chair| 3500|
# | Tablet|30000|
# |  Table|12000|
# |  Shoes| 2500|
# |  Watch| 8000|
# |     TV|45000|
# |   Desk|15000|
# | Mobile|28000|
# +-------+-----+

# %%
df.filter(df.city=="Hyderabad").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|     Pending|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+

# %%
df.filter(df.category=="Electronics").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|     Pending|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+

# %%
df.filter(df.category=="Furniture").show()
# Out:
# +--------+-------------+---------+---------+-------+--------+-----+------------+
# |order_id|customer_name|     city| category|product|quantity|price|order_status|
# +--------+-------------+---------+---------+-------+--------+-----+------------+
# |       3|   Amit Kumar|   Mumbai|Furniture|  Chair|       4| 3500|     Pending|
# |       5|   Farhan Ali|    Delhi|Furniture|  Table|       2|12000|   Delivered|
# |       9|    Kiran Rao|Hyderabad|Furniture|   Desk|       1|15000|   Delivered|
# +--------+-------------+---------+---------+-------+--------+-----+------------+

# %%
df.filter(df.price>30000).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|     Pending|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+

# %%
df.filter(df.quantity>1).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+

# %%
df.filter(df.order_status =="Delivered").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+

# %%
df.filter(df.order_status =="Pending").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|     Pending|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+

# %%
df.filter(df.order_status =="Cancelled").show()
# Out:
# +--------+-------------+-------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|   city|   category|product|quantity|price|order_status|
# +--------+-------------+-------+-----------+-------+--------+-----+------------+
# |       4|  Sneha Patel|Chennai|Electronics| Tablet|       1|30000|   Cancelled|
# +--------+-------------+-------+-----------+-------+--------+-----+------------+

# %%
df.filter((df.city=="Hyderabad") | (df.city=="Mumbai")).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|     Pending|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+

# %%
df.filter((df.category=="Electronics")|(df.category=="Furniture")).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|     Pending|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|
# ...

# %%
df.filter(df.price.between(10000,50000)).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+

# %%
df.orderBy(df.price).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|
# ...

# %%
df.orderBy(df.price.desc()).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|     Pending|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|
# ...

# %%
df.orderBy(df.city,df.price).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|     Pending|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|
# ...

# %%
from pyspark.sql.functions import *
df=df.withColumn("total_amount",df.quantity*df.price)
df.show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|     Pending|       65000|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|       14000|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|       24000|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|        7500|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|        8000|
# ...

# %%
df=df.withColumn("discount",df.total_amount*0.1)
df.show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|     Pending|       65000|  6500.0|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|       14000|  1400.0|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|  3000.0|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|       24000|  2400.0|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|        7500|   750.0|
# ...

# %%
df=df.withColumn("final_amount",df.total_amount-df.discount)
df.show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|     Pending|       65000|  6500.0|     58500.0|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|       14000|  1400.0|     12600.0|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|  3000.0|     27000.0|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|       24000|  2400.0|     21600.0|
# ...

# %%
df=df.withColumnRenamed("customer_name","name")
df.show()
# Out:
# +--------+------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|        name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       1|Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|     Pending|       65000|  6500.0|     58500.0|
# |       2| Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |       3|  Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|       14000|  1400.0|     12600.0|
# |       4| Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|  3000.0|     27000.0|
# |       5|  Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|       24000|  2400.0|     21600.0|
# ...

# %%
df=df.withColumnRenamed("order_status","status")
df.show()
# Out:
# +--------+------------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+
# |order_id|        name|     city|   category|product|quantity|price|   status|total_amount|discount|final_amount|
# +--------+------------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+
# |       1|Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|  Pending|       65000|  6500.0|     58500.0|
# |       2| Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|Delivered|       50000|  5000.0|     45000.0|
# |       3|  Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|  Pending|       14000|  1400.0|     12600.0|
# |       4| Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|Cancelled|       30000|  3000.0|     27000.0|
# |       5|  Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|Delivered|       24000|  2400.0|     21600.0|
# ...

# %%
from pyspark.sql.functions import sum,mean
df.select(sum("total_amount")).show()
# Out:
# +-----------------+
# |sum(total_amount)|
# +-----------------+
# |           286500|
# +-----------------+

# %%
df.select(mean("total_amount")).show()
# Out:
# +-----------------+
# |avg(total_amount)|
# +-----------------+
# |          28650.0|
# +-----------------+

# %%
df.select(max("total_amount")).show()
# Out:
# +-----------------+
# |max(total_amount)|
# +-----------------+
# |            65000|
# +-----------------+

# %%
df.select(min("total_amount")).show()
# Out:
# +-----------------+
# |min(total_amount)|
# +-----------------+
# |             7500|
# +-----------------+

# %%
df.select(count("order_id")).show()
# Out:
# +---------------+
# |count(order_id)|
# +---------------+
# |             10|
# +---------------+

# %%
df.groupBy("city").count().show()
# Out:
# +---------+-----+
# |     city|count|
# +---------+-----+
# |Bangalore|    2|
# |  Chennai|    1|
# |   Mumbai|    2|
# |    Delhi|    1|
# |Hyderabad|    3|
# |     Pune|    1|
# +---------+-----+

# %%
df.groupBy("category").count().show()
# Out:
# +-----------+-----+
# |   category|count|
# +-----------+-----+
# |Electronics|    5|
# |  Furniture|    3|
# |    Fashion|    2|
# +-----------+-----+

# %%
df.groupBy("status").count().show()
# Out:
# +---------+-----+
# |   status|count|
# +---------+-----+
# |Cancelled|    1|
# |Delivered|    6|
# |  Pending|    3|
# +---------+-----+

# %%
df.groupBy("city").sum("total_amount").show()
# Out:
# +---------+-----------------+
# |     city|sum(total_amount)|
# +---------+-----------------+
# |Bangalore|            95000|
# |  Chennai|            30000|
# |   Mumbai|            42000|
# |    Delhi|            24000|
# |Hyderabad|            87500|
# |     Pune|             8000|
# +---------+-----------------+

# %%
df.groupBy("category").sum("total_amount").show()
# Out:
# +-----------+-----------------+
# |   category|sum(total_amount)|
# +-----------+-----------------+
# |Electronics|           218000|
# |  Furniture|            53000|
# |    Fashion|            15500|
# +-----------+-----------------+

# %%
df.groupBy("product").sum("total_amount").show()
# Out:
# +-------+-----------------+
# |product|sum(total_amount)|
# +-------+-----------------+
# |  Chair|            14000|
# | Laptop|            65000|
# |  Table|            24000|
# | Mobile|            78000|
# | Tablet|            30000|
# |     TV|            45000|
# |   Desk|            15000|
# |  Shoes|             7500|
# |  Watch|             8000|
# +-------+-----------------+

# %%
df.groupBy("category").mean("price").show()
# Out:
# +-----------+------------------+
# |   category|        avg(price)|
# +-----------+------------------+
# |Electronics|           38600.0|
# |  Furniture|10166.666666666666|
# |    Fashion|            5250.0|
# +-----------+------------------+

# %%
df.groupBy("category").max("price").show()
# Out:
# +-----------+----------+
# |   category|max(price)|
# +-----------+----------+
# |Electronics|     65000|
# |  Furniture|     15000|
# |    Fashion|      8000|
# +-----------+----------+

# %%
df.groupBy("category").min("price").show()
# Out:
# +-----------+----------+
# |   category|min(price)|
# +-----------+----------+
# |Electronics|     25000|
# |  Furniture|      3500|
# |    Fashion|      2500|
# +-----------+----------+

# %%
df.select("city").distinct().show()
# Out:
# +---------+
# |     city|
# +---------+
# |Bangalore|
# |  Chennai|
# |   Mumbai|
# |    Delhi|
# |Hyderabad|
# |     Pune|
# +---------+

# %%
df.select("category").distinct().show()
# Out:
# +-----------+
# |   category|
# +-----------+
# |Electronics|
# |  Furniture|
# |    Fashion|
# +-----------+

# %%
df.select(df.status).distinct().show()
# Out:
# +---------+
# |   status|
# +---------+
# |Cancelled|
# |Delivered|
# |  Pending|
# +---------+

# %%
df.orderBy(df.total_amount.desc()).limit(3).show()
# Out:
# +--------+------------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+
# |order_id|        name|     city|   category|product|quantity|price|   status|total_amount|discount|final_amount|
# +--------+------------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+
# |       1|Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|  Pending|       65000|  6500.0|     58500.0|
# |       2| Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|Delivered|       50000|  5000.0|     45000.0|
# |       8|  Meera Nair|Bangalore|Electronics|     TV|       1|45000|Delivered|       45000|  4500.0|     40500.0|
# +--------+------------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+

# %%
min_total_amount = df.select(min("total_amount")).first()[0]
df.filter(df.total_amount == min_total_amount).show()
# Out:
# +--------+----------+---------+--------+-------+--------+-----+---------+------------+--------+------------+
# |order_id|      name|     city|category|product|quantity|price|   status|total_amount|discount|final_amount|
# +--------+----------+---------+--------+-------+--------+-----+---------+------------+--------+------------+
# |       6|Neha Singh|Hyderabad| Fashion|  Shoes|       3| 2500|Delivered|        7500|   750.0|      6750.0|
# +--------+----------+---------+--------+-------+--------+-----+---------+------------+--------+------------+

# %%
df.filter(df.product.like("M%")).show()
# Out:
# +--------+-----------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+
# |order_id|       name|     city|   category|product|quantity|price|   status|total_amount|discount|final_amount|
# +--------+-----------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+
# |       2|Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|Delivered|       50000|  5000.0|     45000.0|
# |      10| Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|Delivered|       28000|  2800.0|     25200.0|
# +--------+-----------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+

# %%
df.filter(df.name.like("%a%")).show()
# Out:
# +--------+------------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+
# |order_id|        name|     city|   category|product|quantity|price|   status|total_amount|discount|final_amount|
# +--------+------------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+
# |       1|Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|  Pending|       65000|  6500.0|     58500.0|
# |       2| Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|Delivered|       50000|  5000.0|     45000.0|
# |       3|  Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|  Pending|       14000|  1400.0|     12600.0|
# |       4| Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|Cancelled|       30000|  3000.0|     27000.0|
# |       5|  Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|Delivered|       24000|  2400.0|     21600.0|
# ...

# %%
df.filter(df.name.like("%a%")).show()
# Out:
# +--------+------------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+
# |order_id|        name|     city|   category|product|quantity|price|   status|total_amount|discount|final_amount|
# +--------+------------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+
# |       1|Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|  Pending|       65000|  6500.0|     58500.0|
# |       2| Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|Delivered|       50000|  5000.0|     45000.0|
# |       3|  Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|  Pending|       14000|  1400.0|     12600.0|
# |       4| Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|Cancelled|       30000|  3000.0|     27000.0|
# |       5|  Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|Delivered|       24000|  2400.0|     21600.0|
# ...

# %%
df.filter(df.product.like("%o%")).show()
# Out:
# +--------+------------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+
# |order_id|        name|     city|   category|product|quantity|price|   status|total_amount|discount|final_amount|
# +--------+------------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+
# |       1|Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|  Pending|       65000|  6500.0|     58500.0|
# |       2| Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|Delivered|       50000|  5000.0|     45000.0|
# |       6|  Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|Delivered|        7500|   750.0|      6750.0|
# |      10|  Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|Delivered|       28000|  2800.0|     25200.0|
# +--------+------------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+

# %%
df=df.withColumn("order_category",when(df.total_amount>=50000,"High").when(df.total_amount>=20000,"Medium").otherwise("Low"))
df.show()
# Out:
# +--------+------------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+--------------+
# |order_id|        name|     city|   category|product|quantity|price|   status|total_amount|discount|final_amount|order_category|
# +--------+------------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+--------------+
# |       1|Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|  Pending|       65000|  6500.0|     58500.0|          High|
# |       2| Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|Delivered|       50000|  5000.0|     45000.0|          High|
# |       3|  Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|  Pending|       14000|  1400.0|     12600.0|           Low|
# |       4| Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|Cancelled|       30000|  3000.0|     27000.0|        Medium|
# ...

# %%
df.groupBy("order_category").count().show()
# Out:
# +--------------+-----+
# |order_category|count|
# +--------------+-----+
# |          High|    2|
# |           Low|    4|
# |        Medium|    4|
# +--------------+-----+

# %%
df.filter(df.status=="Delivered").show()
# Out:
# +--------+-----------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+--------------+
# |order_id|       name|     city|   category|product|quantity|price|   status|total_amount|discount|final_amount|order_category|
# +--------+-----------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+--------------+
# |       2|Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|Delivered|       50000|  5000.0|     45000.0|          High|
# |       5| Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|Delivered|       24000|  2400.0|     21600.0|        Medium|
# |       6| Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|Delivered|        7500|   750.0|      6750.0|           Low|
# |       8| Meera Nair|Bangalore|Electronics|     TV|       1|45000|Delivered|       45000|  4500.0|     40500.0|        Medium|
# ...

# %%
df.filter(df.status=='Delivered').groupBy("city").sum("total_amount").show()
# Out:
# +---------+-----------------+
# |     city|sum(total_amount)|
# +---------+-----------------+
# |Bangalore|            95000|
# |    Delhi|            24000|
# |   Mumbai|            28000|
# |Hyderabad|            22500|
# +---------+-----------------+

# %%
df.show()
# Out:
# +--------+------------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+--------------+
# |order_id|        name|     city|   category|product|quantity|price|   status|total_amount|discount|final_amount|order_category|
# +--------+------------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+--------------+
# |       1|Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|  Pending|       65000|  6500.0|     58500.0|          High|
# |       2| Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|Delivered|       50000|  5000.0|     45000.0|          High|
# |       3|  Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|  Pending|       14000|  1400.0|     12600.0|           Low|
# |       4| Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|Cancelled|       30000|  3000.0|     27000.0|        Medium|
# ...
