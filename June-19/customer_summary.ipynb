# %%
customer_table=spark.read.table("customer1")
display(customer_table)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>city</th><th>membership</th></tr></thead><tbody><tr><td>1</td><td>John</td><td>Chennai</td><td>Gold</td></tr><tr><td>2</td><td>Mary</td><td>Hyderabad</td><td>Silver</td></tr><tr><td>3</td><td>Mike</td><td>Mumbai</td><td>Gold</td></tr><tr><td>4</td><td>Jane</td><td>Delhi</td><td>Bronze</td></tr><tr><td>5</td><td>Mary</td><td>Chennai</td><td>Gold</td></tr><tr><td>6</td><td>John</td><td>Hyderabad</td><td>Bronze</td></tr><tr><td>7</td><td>Mary</td><td>Mumbai</td><td>Gold</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import count
customer_summary=customer_table.groupBy("city").agg(count("id"))
display(customer_summary)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>count(id)</th></tr></thead><tbody><tr><td>Chennai</td><td>2</td></tr><tr><td>Hyderabad</td><td>2</td></tr><tr><td>Mumbai</td><td>2</td></tr><tr><td>Delhi</td><td>1</td></tr></tbody></table></div>
