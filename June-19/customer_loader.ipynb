# %%
customer=[(1,'John','Chennai','Gold'),(2,'Mary','Hyderabad','Silver'),(3,'Mike','Mumbai','Gold'),(4,'Jane','Delhi','Bronze'),(5,'Mary','Chennai','Gold'),(6,'John','Hyderabad','Bronze'),(7,'Mary','Mumbai','Gold')]
customer_df=spark.createDataFrame(customer,['id','name','city','membership'])

# %%
customer_df.write.mode("overwrite").saveAsTable("customer1")
