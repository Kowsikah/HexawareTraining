# %%
emp_data=[(1,"John",23,50000),(2,"Mary",25,60000),(3,"Robert",27,70000),(4,"Mike",30,80000),(5,"Sarah",32,90000),(6,"David",35,100000),(7,"Emily",38,110000),(8,"Daniel",40,120000),
]

# %%
columns=['id','name','age','salary']
df=spark.createDataFrame(data=emp_data,schema=columns)
display(df)
print("Employee Load created")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th><th>salary</th></tr></thead><tbody><tr><td>1</td><td>John</td><td>23</td><td>50000</td></tr><tr><td>2</td><td>Mary</td><td>25</td><td>60000</td></tr><tr><td>3</td><td>Robert</td><td>27</td><td>70000</td></tr><tr><td>4</td><td>Mike</td><td>30</td><td>80000</td></tr><tr><td>5</td><td>Sarah</td><td>32</td><td>90000</td></tr><tr><td>6</td><td>David</td><td>35</td><td>100000</td></tr><tr><td>7</td><td>Emily</td><td>38</td><td>110000</td></tr><tr><td>8</td><td>Daniel</td><td>40</td><td>120000</td></tr></tbody></table></div>
# Employee Load created
