# %%
transactions = [
"DEPOSIT",
"WITHDRAW",
"TRANSFER",
"DEPOSIT",
"BALANCE_CHECK",
"TRANSFER",
"DEPOSIT",
"WITHDRAW",
"LOAN_PAYMENT",
"DEPOSIT",
"TRANSFER",
"WITHDRAW",
"DEPOSIT",
"BALANCE_CHECK",
"TRANSFER",
"DEPOSIT",
"WITHDRAW",
"LOAN_PAYMENT",
"TRANSFER",
"DEPOSIT",
"WITHDRAW",
"DEPOSIT",
"TRANSFER",
"BALANCE_CHECK",
"WITHDRAW",
"DEPOSIT",
"TRANSFER",
"LOAN_PAYMENT",
"DEPOSIT",
"WITHDRAW",
"TRANSFER",
"DEPOSIT",
"BALANCE_CHECK",
"TRANSFER",
"WITHDRAW",
"DEPOSIT",
"TRANSFER",

"LOAN_PAYMENT",
"DEPOSIT",
"WITHDRAW",
"TRANSFER",
"BALANCE_CHECK",
"DEPOSIT",
"TRANSFER",
"WITHDRAW",
"LOAN_PAYMENT",
"DEPOSIT",
"TRANSFER",
"BALANCE_CHECK",
"DEPOSIT"
]

# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName("Bank").getOrCreate()

# %%
rdd = spark.sparkContext.parallelize(transactions)

# %%
rdd.collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT']

# %%
rdd.count()
# Out:
# 50

# %%
rdd.take(1)
# Out:
# ['DEPOSIT']

# %%
rdd.take(15)
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER']

# %%
result=rdd.distinct()
result.collect()
# Out:
# ['DEPOSIT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'LOAN_PAYMENT']

# %%
result.count()
# Out:
# 5

# %%
result.sortBy(lambda x:x).collect()
# Out:
# ['BALANCE_CHECK', 'DEPOSIT', 'LOAN_PAYMENT', 'TRANSFER', 'WITHDRAW']

# %%
lower_case=rdd.map(lambda x:x.lower())
lower_case.collect()
# Out:
# ['deposit',
#  'withdraw',
#  'transfer',
#  'deposit',
#  'balance_check',
#  'transfer',
#  'deposit',
#  'withdraw',
#  'loan_payment',
#  'deposit',
#  'transfer',
#  'withdraw',
#  'deposit',
#  'balance_check',
#  'transfer',
#  'deposit',
#  'withdraw',
#  'loan_payment',
#  'transfer',
#  'deposit',
#  'withdraw',
#  'deposit',
#  'transfer',
#  'balance_check',
#  'withdraw',
#  'deposit',
#  'transfer',
#  'loan_payment',
#  'deposit',
#  'withdraw',
#  'transfer',
#  'deposit',
#  'balance_check',
#  'transfer',
#  'withdraw',
#  'deposit',
#  'transfer',
#  'loan_payment',
#  'deposit',
#  'withdraw',
#  'transfer',
#  'balance_check',
#  'deposit',
#  'transfer',
#  'withdraw',
#  'loan_payment',
#  'deposit',
#  'transfer',
#  'balance_check',
#  'deposit']

# %%
upper_case=rdd.map(lambda x:x.upper()).collect()
print(upper_case)
# Out:
# ['DEPOSIT', 'WITHDRAW', 'TRANSFER', 'DEPOSIT', 'BALANCE_CHECK', 'TRANSFER', 'DEPOSIT', 'WITHDRAW', 'LOAN_PAYMENT', 'DEPOSIT', 'TRANSFER', 'WITHDRAW', 'DEPOSIT', 'BALANCE_CHECK', 'TRANSFER', 'DEPOSIT', 'WITHDRAW', 'LOAN_PAYMENT', 'TRANSFER', 'DEPOSIT', 'WITHDRAW', 'DEPOSIT', 'TRANSFER', 'BALANCE_CHECK', 'WITHDRAW', 'DEPOSIT', 'TRANSFER', 'LOAN_PAYMENT', 'DEPOSIT', 'WITHDRAW', 'TRANSFER', 'DEPOSIT', 'BALANCE_CHECK', 'TRANSFER', 'WITHDRAW', 'DEPOSIT', 'TRANSFER', 'LOAN_PAYMENT', 'DEPOSIT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'DEPOSIT', 'TRANSFER', 'WITHDRAW', 'LOAN_PAYMENT', 'DEPOSIT', 'TRANSFER', 'BALANCE_CHECK', 'DEPOSIT']

# %%
word_len=rdd.map(lambda x:(x,len(x)))
print(word_len.collect())
# Out:
# [('DEPOSIT', 7), ('WITHDRAW', 8), ('TRANSFER', 8), ('DEPOSIT', 7), ('BALANCE_CHECK', 13), ('TRANSFER', 8), ('DEPOSIT', 7), ('WITHDRAW', 8), ('LOAN_PAYMENT', 12), ('DEPOSIT', 7), ('TRANSFER', 8), ('WITHDRAW', 8), ('DEPOSIT', 7), ('BALANCE_CHECK', 13), ('TRANSFER', 8), ('DEPOSIT', 7), ('WITHDRAW', 8), ('LOAN_PAYMENT', 12), ('TRANSFER', 8), ('DEPOSIT', 7), ('WITHDRAW', 8), ('DEPOSIT', 7), ('TRANSFER', 8), ('BALANCE_CHECK', 13), ('WITHDRAW', 8), ('DEPOSIT', 7), ('TRANSFER', 8), ('LOAN_PAYMENT', 12), ('DEPOSIT', 7), ('WITHDRAW', 8), ('TRANSFER', 8), ('DEPOSIT', 7), ('BALANCE_CHECK', 13), ('TRANSFER', 8), ('WITHDRAW', 8), ('DEPOSIT', 7), ('TRANSFER', 8), ('LOAN_PAYMENT', 12), ('DEPOSIT', 7), ('WITHDRAW', 8), ('TRANSFER', 8), ('BALANCE_CHECK', 13), ('DEPOSIT', 7), ('TRANSFER', 8), ('WITHDRAW', 8), ('LOAN_PAYMENT', 12), ('DEPOSIT', 7), ('TRANSFER', 8), ('BALANCE_CHECK', 13), ('DEPOSIT', 7)]

# %%
result_trans=rdd.filter(lambda x:x=="DEPOSIT")
result_trans.collect()
# Out:
# ['DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT']

# %%
result_trans=rdd.filter(lambda x:x=="WITHDRAW")
result_trans.collect()
# Out:
# ['WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW']

# %%
result_trans=rdd.filter(lambda x:x=="TRANSFER")
result_trans.collect()
# Out:
# ['TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER']

# %%
result_trans=rdd.filter(lambda x:x=="LOAN_PAYMENT")
result_trans.collect()
# Out:
# ['LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT']

# %%
result_trans=rdd.filter(lambda x:"CHECK" in x)
result_trans.collect()
# Out:
# ['BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK']

# %%
result1=rdd.filter(lambda x:x!='DEPOSIT')
result1.collect()
# Out:
# ['WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'WITHDRAW',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'BALANCE_CHECK']

# %%
result2=rdd.filter(lambda x:x!='TRANSFER')
result2.collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'DEPOSIT']

# %%
result3=rdd.filter(lambda x:len(x)>8)
result3.collect()
# Out:
# ['BALANCE_CHECK',
#  'LOAN_PAYMENT',
#  'BALANCE_CHECK',
#  'LOAN_PAYMENT',
#  'BALANCE_CHECK',
#  'LOAN_PAYMENT',
#  'BALANCE_CHECK',
#  'LOAN_PAYMENT',
#  'BALANCE_CHECK',
#  'LOAN_PAYMENT',
#  'BALANCE_CHECK']

# %%
result3=rdd.filter(lambda x:len(x)<10)
result3.collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'DEPOSIT']

# %%
result5=rdd.filter(lambda x:x.startswith('B'))
result5.collect()
# Out:
# ['BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK']

# %%
result6=rdd.map(lambda x:"BANK_"+x)
result6.collect()
# Out:
# ['BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_TRANSFER',
#  'BANK_DEPOSIT',
#  'BANK_BALANCE_CHECK',
#  'BANK_TRANSFER',
#  'BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_LOAN_PAYMENT',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
#  'BANK_WITHDRAW',
#  'BANK_DEPOSIT',
#  'BANK_BALANCE_CHECK',
#  'BANK_TRANSFER',
#  'BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_LOAN_PAYMENT',
#  'BANK_TRANSFER',
#  'BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
#  'BANK_BALANCE_CHECK',
#  'BANK_WITHDRAW',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
#  'BANK_LOAN_PAYMENT',
#  'BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_TRANSFER',
#  'BANK_DEPOSIT',
#  'BANK_BALANCE_CHECK',
#  'BANK_TRANSFER',
#  'BANK_WITHDRAW',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
#  'BANK_LOAN_PAYMENT',
#  'BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_TRANSFER',
#  'BANK_BALANCE_CHECK',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
#  'BANK_WITHDRAW',
#  'BANK_LOAN_PAYMENT',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
# ...

# %%
result7=rdd.map(lambda x:x+"_2025")
result7.collect()
# Out:
# ['DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'TRANSFER_2025',
#  'DEPOSIT_2025',
#  'BALANCE_CHECK_2025',
#  'TRANSFER_2025',
#  'DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'LOAN_PAYMENT_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
#  'WITHDRAW_2025',
#  'DEPOSIT_2025',
#  'BALANCE_CHECK_2025',
#  'TRANSFER_2025',
#  'DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'LOAN_PAYMENT_2025',
#  'TRANSFER_2025',
#  'DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
#  'BALANCE_CHECK_2025',
#  'WITHDRAW_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
#  'LOAN_PAYMENT_2025',
#  'DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'TRANSFER_2025',
#  'DEPOSIT_2025',
#  'BALANCE_CHECK_2025',
#  'TRANSFER_2025',
#  'WITHDRAW_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
#  'LOAN_PAYMENT_2025',
#  'DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'TRANSFER_2025',
#  'BALANCE_CHECK_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
#  'WITHDRAW_2025',
#  'LOAN_PAYMENT_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
# ...

# %%
result8=rdd.map(lambda x:(x,len(x)))
result8.collect()
# Out:
# [('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('BALANCE_CHECK', 13),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('BALANCE_CHECK', 13),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('LOAN_PAYMENT', 12),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('BALANCE_CHECK', 13),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('BALANCE_CHECK', 13),
#  ('TRANSFER', 8),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('TRANSFER', 8),
#  ('BALANCE_CHECK', 13),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('WITHDRAW', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
# ...

# %%
result_9=rdd.map(lambda x:x.replace("DEPOSIT","CASH_DEPOSIT"))
result_9.collect()
# Out:
# ['CASH_DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'CASH_DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'CASH_DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'CASH_DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'CASH_DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'CASH_DEPOSIT',
#  'WITHDRAW',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'CASH_DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'CASH_DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'CASH_DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'CASH_DEPOSIT']

# %%
result_10=rdd.map(lambda x:x.replace("WITHDRAW","CASH_WITHDRAWAL"))
result_10.collect()
# Out:
# ['DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'CASH_WITHDRAWAL',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'CASH_WITHDRAWAL',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'CASH_WITHDRAWAL',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'TRANSFER',
#  'CASH_WITHDRAWAL',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT']

# %%
result_11=rdd.map(lambda x:x[::-1])
result_11.collect()
# Out:
# ['TISOPED',
#  'WARDHTIW',
#  'REFSNART',
#  'TISOPED',
#  'KCEHC_ECNALAB',
#  'REFSNART',
#  'TISOPED',
#  'WARDHTIW',
#  'TNEMYAP_NAOL',
#  'TISOPED',
#  'REFSNART',
#  'WARDHTIW',
#  'TISOPED',
#  'KCEHC_ECNALAB',
#  'REFSNART',
#  'TISOPED',
#  'WARDHTIW',
#  'TNEMYAP_NAOL',
#  'REFSNART',
#  'TISOPED',
#  'WARDHTIW',
#  'TISOPED',
#  'REFSNART',
#  'KCEHC_ECNALAB',
#  'WARDHTIW',
#  'TISOPED',
#  'REFSNART',
#  'TNEMYAP_NAOL',
#  'TISOPED',
#  'WARDHTIW',
#  'REFSNART',
#  'TISOPED',
#  'KCEHC_ECNALAB',
#  'REFSNART',
#  'WARDHTIW',
#  'TISOPED',
#  'REFSNART',
#  'TNEMYAP_NAOL',
#  'TISOPED',
#  'WARDHTIW',
#  'REFSNART',
#  'KCEHC_ECNALAB',
#  'TISOPED',
#  'REFSNART',
#  'WARDHTIW',
#  'TNEMYAP_NAOL',
#  'TISOPED',
#  'REFSNART',
#  'KCEHC_ECNALAB',
#  'TISOPED']

# %%
result12=rdd.map(lambda x:x[0:3])
result12.collect()
# Out:
# ['DEP',
#  'WIT',
#  'TRA',
#  'DEP',
#  'BAL',
#  'TRA',
#  'DEP',
#  'WIT',
#  'LOA',
#  'DEP',
#  'TRA',
#  'WIT',
#  'DEP',
#  'BAL',
#  'TRA',
#  'DEP',
#  'WIT',
#  'LOA',
#  'TRA',
#  'DEP',
#  'WIT',
#  'DEP',
#  'TRA',
#  'BAL',
#  'WIT',
#  'DEP',
#  'TRA',
#  'LOA',
#  'DEP',
#  'WIT',
#  'TRA',
#  'DEP',
#  'BAL',
#  'TRA',
#  'WIT',
#  'DEP',
#  'TRA',
#  'LOA',
#  'DEP',
#  'WIT',
#  'TRA',
#  'BAL',
#  'DEP',
#  'TRA',
#  'WIT',
#  'LOA',
#  'DEP',
#  'TRA',
#  'BAL',
#  'DEP']

# %%
result13=rdd.map(lambda x:x[0:4])
result13.collect()
# Out:
# ['DEPO',
#  'WITH',
#  'TRAN',
#  'DEPO',
#  'BALA',
#  'TRAN',
#  'DEPO',
#  'WITH',
#  'LOAN',
#  'DEPO',
#  'TRAN',
#  'WITH',
#  'DEPO',
#  'BALA',
#  'TRAN',
#  'DEPO',
#  'WITH',
#  'LOAN',
#  'TRAN',
#  'DEPO',
#  'WITH',
#  'DEPO',
#  'TRAN',
#  'BALA',
#  'WITH',
#  'DEPO',
#  'TRAN',
#  'LOAN',
#  'DEPO',
#  'WITH',
#  'TRAN',
#  'DEPO',
#  'BALA',
#  'TRAN',
#  'WITH',
#  'DEPO',
#  'TRAN',
#  'LOAN',
#  'DEPO',
#  'WITH',
#  'TRAN',
#  'BALA',
#  'DEPO',
#  'TRAN',
#  'WITH',
#  'LOAN',
#  'DEPO',
#  'TRAN',
#  'BALA',
#  'DEPO']

# %%
result14=rdd.map(lambda x:(x,x[0]))
result14.collect()
# Out:
# [('DEPOSIT', 'D'),
#  ('WITHDRAW', 'W'),
#  ('TRANSFER', 'T'),
#  ('DEPOSIT', 'D'),
#  ('BALANCE_CHECK', 'B'),
#  ('TRANSFER', 'T'),
#  ('DEPOSIT', 'D'),
#  ('WITHDRAW', 'W'),
#  ('LOAN_PAYMENT', 'L'),
#  ('DEPOSIT', 'D'),
#  ('TRANSFER', 'T'),
#  ('WITHDRAW', 'W'),
#  ('DEPOSIT', 'D'),
#  ('BALANCE_CHECK', 'B'),
#  ('TRANSFER', 'T'),
#  ('DEPOSIT', 'D'),
#  ('WITHDRAW', 'W'),
#  ('LOAN_PAYMENT', 'L'),
#  ('TRANSFER', 'T'),
#  ('DEPOSIT', 'D'),
#  ('WITHDRAW', 'W'),
#  ('DEPOSIT', 'D'),
#  ('TRANSFER', 'T'),
#  ('BALANCE_CHECK', 'B'),
#  ('WITHDRAW', 'W'),
#  ('DEPOSIT', 'D'),
#  ('TRANSFER', 'T'),
#  ('LOAN_PAYMENT', 'L'),
#  ('DEPOSIT', 'D'),
#  ('WITHDRAW', 'W'),
#  ('TRANSFER', 'T'),
#  ('DEPOSIT', 'D'),
#  ('BALANCE_CHECK', 'B'),
#  ('TRANSFER', 'T'),
#  ('WITHDRAW', 'W'),
#  ('DEPOSIT', 'D'),
#  ('TRANSFER', 'T'),
#  ('LOAN_PAYMENT', 'L'),
#  ('DEPOSIT', 'D'),
#  ('WITHDRAW', 'W'),
#  ('TRANSFER', 'T'),
#  ('BALANCE_CHECK', 'B'),
#  ('DEPOSIT', 'D'),
#  ('TRANSFER', 'T'),
# ...

# %%
result15=rdd.distinct()
result15.collect()
# Out:
# ['DEPOSIT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'LOAN_PAYMENT']

# %%
result15.count()
# Out:
# 5

# %%
result15.sortBy(lambda x:x).collect()
# Out:
# ['BALANCE_CHECK', 'DEPOSIT', 'LOAN_PAYMENT', 'TRANSFER', 'WITHDRAW']

# %%
result15.filter(lambda x:"PAYMENT" in x).collect()
# Out:
# ['LOAN_PAYMENT']

# %%
result15.filter(lambda x:"CHECK" in x).collect()
# Out:
# ['BALANCE_CHECK']

# %%
freq_rdd=rdd.map(lambda x:(x,1)).reduceByKey(lambda x,y:x+y)
freq_rdd.collect()
# Out:
# [('DEPOSIT', 16),
#  ('WITHDRAW', 10),
#  ('TRANSFER', 13),
#  ('BALANCE_CHECK', 6),
#  ('LOAN_PAYMENT', 5)]

# %%
most_frequent=freq_rdd.max(key=lambda x:x[1])
print(most_frequent)
# Out:
# ('DEPOSIT', 16)

# %%
least_frequent=freq_rdd.min(key=lambda x:x[1])
print(least_frequent)
# Out:
# ('LOAN_PAYMENT', 5)

# %%
result_16=freq_rdd.filter(lambda x:x[1]>5)
result_16.collect()
# Out:
# [('DEPOSIT', 16), ('WITHDRAW', 10), ('TRANSFER', 13), ('BALANCE_CHECK', 6)]

# %%
extra_transactions = [
"DEPOSIT",
"ATM_WITHDRAWAL",
"TRANSFER",

"MOBILE_RECHARGE",
"BALANCE_CHECK"
]
rdd2 = spark.sparkContext.parallelize(extra_transactions)

# %%
result17=rdd.union(rdd2)
result17.collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'DEPOSIT',
#  'ATM_WITHDRAWAL',
#  'TRANSFER',
#  'MOBILE_RECHARGE',
#  'BALANCE_CHECK']

# %%
result17.count()
# Out:
# 55

# %%
result17.distinct().collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'LOAN_PAYMENT',
#  'ATM_WITHDRAWAL',
#  'MOBILE_RECHARGE']

# %%
rdd2.subtract(rdd).collect()
# Out:
# ['ATM_WITHDRAWAL', 'MOBILE_RECHARGE']

# %%
result18=rdd.intersection(rdd2)
print(result18.collect())
# Out:
# ['DEPOSIT', 'TRANSFER', 'BALANCE_CHECK']

# %%
result18.count()
# Out:
# 3

# %%
result18.sortBy(lambda x:x)
result18.collect()
# Out:
# ['DEPOSIT', 'TRANSFER', 'BALANCE_CHECK']

# %%
result18.filter(lambda x:"CHECK" in x).collect()
# Out:
# ['BALANCE_CHECK']

# %%
result18.filter(lambda x:"TRANSFER" in x).collect()
# Out:
# ['TRANSFER']

# %%
amounts = [
500,1200,3000,4500,800,950,
1100,2500,4000,6000,

750,1800,2200,3300,4700,
5200,1500,2600,3700,4800,
5900,6200,700,900,1400,
1750,2100,2900,3600,4300,
5100,5800,6500,7200,8100,
9200,10500,12000,13500,15000,
17000,19000,22000,25000,28000,
30000,32000,35000,38000,40000
]
amount_rdd = spark.sparkContext.parallelize(amounts)

# %%
total_transaction=amount_rdd.sum()
print(total_transaction)
# Out:
# 463750

# %%
total=amount_rdd.reduce(lambda x,y:x+y)
print(total)
# Out:
# 463750

# %%
average=total/(amount_rdd.count())
print(average)
# Out:
# 9275.0

# %%
max=amount_rdd.max(key=lambda x:x)
print(max)
# Out:
# 40000

# %%
min=amount_rdd.min(key=lambda x:x)
print(min)
# Out:
# 500

# %%
amount_gt_10000=amount_rdd.filter(lambda x:x>10000)
amount_gt_10000.collect()
# Out:
# [10500,
#  12000,
#  13500,
#  15000,
#  17000,
#  19000,
#  22000,
#  25000,
#  28000,
#  30000,
#  32000,
#  35000,
#  38000,
#  40000]

# %%
amount_lt_2000=amount_rdd.filter(lambda x:x<2000)
amount_lt_2000.collect()
# Out:
# [500, 1200, 800, 950, 1100, 750, 1800, 1500, 700, 900, 1400, 1750]

# %%
add_500=amount_rdd.map(lambda x:x+500)
add_500.collect()
# Out:
# [1000,
#  1700,
#  3500,
#  5000,
#  1300,
#  1450,
#  1600,
#  3000,
#  4500,
#  6500,
#  1250,
#  2300,
#  2700,
#  3800,
#  5200,
#  5700,
#  2000,
#  3100,
#  4200,
#  5300,
#  6400,
#  6700,
#  1200,
#  1400,
#  1900,
#  2250,
#  2600,
#  3400,
#  4100,
#  4800,
#  5600,
#  6300,
#  7000,
#  7700,
#  8600,
#  9700,
#  11000,
#  12500,
#  14000,
#  15500,
#  17500,
#  19500,
#  22500,
#  25500,
#  28500,
#  30500,
#  32500,
#  35500,
#  38500,
#  40500]

# %%
bonu_amount=amount_rdd.map(lambda x:x*1.1)
bonu_amount.collect()
# Out:
# [550.0,
#  1320.0,
#  3300.0000000000005,
#  4950.0,
#  880.0000000000001,
#  1045.0,
#  1210.0,
#  2750.0,
#  4400.0,
#  6600.000000000001,
#  825.0000000000001,
#  1980.0000000000002,
#  2420.0,
#  3630.0000000000005,
#  5170.0,
#  5720.000000000001,
#  1650.0000000000002,
#  2860.0000000000005,
#  4070.0000000000005,
#  5280.0,
#  6490.000000000001,
#  6820.000000000001,
#  770.0000000000001,
#  990.0000000000001,
#  1540.0000000000002,
#  1925.0000000000002,
#  2310.0,
#  3190.0000000000005,
#  3960.0000000000005,
#  4730.0,
#  5610.0,
#  6380.000000000001,
#  7150.000000000001,
#  7920.000000000001,
#  8910.0,
#  10120.0,
#  11550.000000000002,
#  13200.000000000002,
#  14850.000000000002,
#  16500.0,
#  18700.0,
#  20900.0,
#  24200.000000000004,
#  27500.000000000004,
#  30800.000000000004,
#  33000.0,
#  35200.0,
#  38500.0,
#  41800.0,
#  44000.0]

# %%
amount_rdd.sortBy(lambda x:x).collect()
# Out:
# [500,
#  700,
#  750,
#  800,
#  900,
#  950,
#  1100,
#  1200,
#  1400,
#  1500,
#  1750,
#  1800,
#  2100,
#  2200,
#  2500,
#  2600,
#  2900,
#  3000,
#  3300,
#  3600,
#  3700,
#  4000,
#  4300,
#  4500,
#  4700,
#  4800,
#  5100,
#  5200,
#  5800,
#  5900,
#  6000,
#  6200,
#  6500,
#  7200,
#  8100,
#  9200,
#  10500,
#  12000,
#  13500,
#  15000,
#  17000,
#  19000,
#  22000,
#  25000,
#  28000,
#  30000,
#  32000,
#  35000,
#  38000,
#  40000]

# %%
amount_rdd.sortBy(lambda x:-x).collect()
# Out:
# [40000,
#  38000,
#  35000,
#  32000,
#  30000,
#  28000,
#  25000,
#  22000,
#  19000,
#  17000,
#  15000,
#  13500,
#  12000,
#  10500,
#  9200,
#  8100,
#  7200,
#  6500,
#  6200,
#  6000,
#  5900,
#  5800,
#  5200,
#  5100,
#  4800,
#  4700,
#  4500,
#  4300,
#  4000,
#  3700,
#  3600,
#  3300,
#  3000,
#  2900,
#  2600,
#  2500,
#  2200,
#  2100,
#  1800,
#  1750,
#  1500,
#  1400,
#  1200,
#  1100,
#  950,
#  900,
#  800,
#  750,
#  700,
#  500]

# %%
amount_rdd.top(3)
# Out:
# [40000, 38000, 35000]

# %%
transactions_above_5000=amount_rdd.filter(lambda x:x>5000).count()
print(transactions_above_5000)
# Out:
# 24

# %%
transactions_above_20000=amount_rdd.filter(lambda x:x>20000).count()
print(transactions_above_20000)
# Out:
# 8

# %%
total_above_10000=amount_rdd.filter(lambda x:x>10000).reduce(lambda x,y:x+y)
print(total_above_10000)
# Out:
# 337000

# %%
customer_comments = [
"service was excellent",
"mobile banking is easy",
"transfer completed quickly",
"deposit process was smooth",
"excellent customer support",
"loan payment completed successfully",
"banking app is excellent",
"service is fast and reliable"
]
comment_rdd = spark.sparkContext.parallelize(customer_comments)

# %%
words=comment_rdd.flatMap(lambda line:line.split(" "))
words.collect()
# Out:
# ['service',
#  'was',
#  'excellent',
#  'mobile',
#  'banking',
#  'is',
#  'easy',
#  'transfer',
#  'completed',
#  'quickly',
#  'deposit',
#  'process',
#  'was',
#  'smooth',
#  'excellent',
#  'customer',
#  'support',
#  'loan',
#  'payment',
#  'completed',
#  'successfully',
#  'banking',
#  'app',
#  'is',
#  'excellent',
#  'service',
#  'is',
#  'fast',
#  'and',
#  'reliable']

# %%
words.count()
# Out:
# 30

# %%
words.distinct().collect()
# Out:
# ['service',
#  'banking',
#  'easy',
#  'transfer',
#  'deposit',
#  'support',
#  'payment',
#  'successfully',
#  'app',
#  'fast',
#  'and',
#  'reliable',
#  'was',
#  'excellent',
#  'mobile',
#  'is',
#  'completed',
#  'quickly',
#  'process',
#  'smooth',
#  'customer',
#  'loan']

# %%
words.sortBy(lambda x:x).collect()
# Out:
# ['and',
#  'app',
#  'banking',
#  'banking',
#  'completed',
#  'completed',
#  'customer',
#  'deposit',
#  'easy',
#  'excellent',
#  'excellent',
#  'excellent',
#  'fast',
#  'is',
#  'is',
#  'is',
#  'loan',
#  'mobile',
#  'payment',
#  'process',
#  'quickly',
#  'reliable',
#  'service',
#  'service',
#  'smooth',
#  'successfully',
#  'support',
#  'transfer',
#  'was',
#  'was']

# %%
frequency_word=words.map(lambda x:(x,1)).reduceByKey(lambda x,y:x+y)
frequency_word.collect()
# Out:
# [('service', 2),
#  ('banking', 2),
#  ('easy', 1),
#  ('transfer', 1),
#  ('deposit', 1),
#  ('support', 1),
#  ('payment', 1),
#  ('successfully', 1),
#  ('app', 1),
#  ('fast', 1),
#  ('and', 1),
#  ('reliable', 1),
#  ('was', 2),
#  ('excellent', 3),
#  ('mobile', 1),
#  ('is', 3),
#  ('completed', 2),
#  ('quickly', 1),
#  ('process', 1),
#  ('smooth', 1),
#  ('customer', 1),
#  ('loan', 1)]

# %%
words.filter(lambda x:"service" in x).collect()
# Out:
# ['service', 'service']

# %%
words.filter(lambda x:"excellent" in x).collect()
# Out:
# ['excellent', 'excellent', 'excellent']

# %%
words.map(lambda x:x.upper()).collect()
# Out:
# ['SERVICE',
#  'WAS',
#  'EXCELLENT',
#  'MOBILE',
#  'BANKING',
#  'IS',
#  'EASY',
#  'TRANSFER',
#  'COMPLETED',
#  'QUICKLY',
#  'DEPOSIT',
#  'PROCESS',
#  'WAS',
#  'SMOOTH',
#  'EXCELLENT',
#  'CUSTOMER',
#  'SUPPORT',
#  'LOAN',
#  'PAYMENT',
#  'COMPLETED',
#  'SUCCESSFULLY',
#  'BANKING',
#  'APP',
#  'IS',
#  'EXCELLENT',
#  'SERVICE',
#  'IS',
#  'FAST',
#  'AND',
#  'RELIABLE']

# %%
longest=words.max(key=lambda x:len(x))
print(longest)
# Out:
# successfully

# %%
shortest=words.min(key=lambda x:len(x))
print(shortest)
# Out:
# is

# %%
most_frequent=frequency_word.max(key=lambda x:x[1])
print(most_frequent)
# Out:
# ('excellent', 3)

# %%
least_frequent=frequency_word.min(key=lambda x:x[1])
print(least_frequent)
# Out:
# ('easy', 1)

# %%
word_b=words.filter(lambda x:x.startswith('b')).count()
print(word_b)
# Out:
# 2

# %%
word_end_ly=words.filter(lambda x:x.endswith('ly')).count()
print(word_end_ly)
# Out:
# 2

# %%
print("Frequency Report")
frequency_data=frequency_word.collect()
for word,word_Count in frequency_data:
    print(f"{word}:{word_Count}")
# Out:
# Frequency Report
# service:2
# banking:2
# easy:1
# transfer:1
# deposit:1
# support:1
# payment:1
# successfully:1
# app:1
# fast:1
# and:1
# reliable:1
# was:2
# excellent:3
# mobile:1
# is:3
# completed:2
# quickly:1
# process:1
# smooth:1
# customer:1
# loan:1

# %%
deposit_count=rdd.filter(lambda x:x=="DEPOSIT").count()
total_count=rdd.count()
deposit_percent=deposit_count/total_count
print(deposit_percent*100)
# Out:
# 32.0

# %%
transfer_count=rdd.filter(lambda x:x=="TRANSFER").count()
total_count=rdd.count()
transfer_percent=transfer_count/total_count
print(transfer_percent*100)
# Out:
# 26.0

# %%
withdraw_count=rdd.filter(lambda x:x=="WITHDRAW").count()
total_count=rdd.count()
withdraw_percent=withdraw_count/total_count
print(withdraw_percent*100)
# Out:
# 20.0

# %%
freq_rdd.max(key=lambda x:x[1])
# Out:
# ('DEPOSIT', 16)

# %%
freq_rdd.min(key=lambda x:x[1])
# Out:
# ('LOAN_PAYMENT', 5)

# %%
print("-----Transaction summary------")
total_c=rdd.count()
print(f"Total transactions: {total_c}")
trans_data=freq_rdd.collect()
print(f"{'Transaction Type':<20} | {'Count':<5} | {'Percentage':<10}")
for trans, count in sorted(trans_data, key=lambda x: x[1], reverse=True):
    pct = (count / total_count) * 100
    print(f"{trans:<20} | {count:<5} | {pct:.2f}%")
# Out:
# -----Transaction summary------
# Total transactions: 50
# Transaction Type     | Count | Percentage
# DEPOSIT              | 16    | 32.00%
# TRANSFER             | 13    | 26.00%
# WITHDRAW             | 10    | 20.00%
# BALANCE_CHECK        | 6     | 12.00%
# LOAN_PAYMENT         | 5     | 10.00%

# %%
print("UNIQUE TRANSACTION REPORT")
print(f"Unique Transactions: {result15.collect()}")
print(f"No of Unique Transactions: {result15.distinct().count()}")
# Out:
# UNIQUE TRANSACTION REPORT
# Unique Transactions: ['DEPOSIT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'LOAN_PAYMENT']
# No of Unique Transactions: 5

# %%
print("Frequency Report")
frequency_data=freq_rdd.collect()
for trans,count in frequency_data:
    print(f"{trans}:{count}")
# Out:
# Frequency Report
# DEPOSIT:16
# WITHDRAW:10
# TRANSFER:13
# BALANCE_CHECK:6
# LOAN_PAYMENT:5

# %%
rdd.distinct().saveAsTextFile("distinct_transaction_output")

# %%
freq_rdd.map(lambda x: f"{x[0]},{x[1]}").saveAsTextFile("transaction_frequencies_output")

# %%
print("Total banking activities",rdd.count())
# Out:
# Total banking activities 50

# %%
freq_rdd.sortBy(lambda x:x[1],ascending=False).take(3)
# Out:
# [('DEPOSIT', 16), ('TRANSFER', 13), ('WITHDRAW', 10)]

# %%
freq_rdd.sortBy(lambda x:x[1]).take(3)
# Out:
# [('LOAN_PAYMENT', 5), ('BALANCE_CHECK', 6), ('WITHDRAW', 10)]

# %%
freq_rdd.sortBy(lambda x:x[0]).collect()
# Out:
# [('BALANCE_CHECK', 6),
#  ('DEPOSIT', 16),
#  ('LOAN_PAYMENT', 5),
#  ('TRANSFER', 13),
#  ('WITHDRAW', 10)]

# %%
print("banking_analytic_report")
print("Total Transaction amount:",total)
print("Average Transaction amount:",average)
print("Maximum Transaction amount",max)
print("Minimum Transaction amount",min)
# Out:
# banking_analytic_report
# Total Transaction amount: 463750
# Average Transaction amount: 9275.0
# Maximum Transaction amount 40000
# Minimum Transaction amount 500

# %%
print("Total Transaction amount:",total)
# Out:
# Total Transaction amount: 463750

# %%
print("Average Transaction amount:",average)

# %%
print("Maximum Transaction amount",max)
# Out:
# Maximum Transaction amount 40000

# %%
print("Minimum Transaction amount",min)
# Out:
# Minimum Transaction amount 500

# %%
print("Bank Transaction Dashboard")
print("Total Transaction amount:",total)
print("Average Transaction amount:",average)
print("Maximum Transaction amount",max)
print("Minimum Transaction amount",min)
print("Total transactions above 5000:",transactions_above_5000)
print("Total transactions above 20000:",transactions_above_20000)
print("Total transactions above 10000:",total_above_10000)
print("Transaction amount above 2000:",amount_lt_2000.collect())
print("Transaction above 10000",amount_gt_10000.collect())
# Out:
# Bank Transaction Dashboard
# Total Transaction amount: 463750
# Average Transaction amount: 9275.0
# Maximum Transaction amount 40000
# Minimum Transaction amount 500
# Total transactions above 5000: 24
# Total transactions above 20000: 8
# Total transactions above 10000: 337000
# Transaction amount above 2000: [500, 1200, 800, 950, 1100, 750, 1800, 1500, 700, 900, 1400, 1750]
# Transaction above 10000 [10500, 12000, 13500, 15000, 17000, 19000, 22000, 25000, 28000, 30000, 32000, 35000, 38000, 40000]
